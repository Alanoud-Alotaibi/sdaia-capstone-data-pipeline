# %% [markdown]
# <a href="https://colab.research.google.com/github/Alanoud-Alotaibi/sdaia-capstone-data-pipeline/blob/main/sdaia-capstone-data-pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
github_token = userdata.get('GITHUB')

username = "Alanoud-Alotaibi"
repo = "sdaia-capstone-data-pipeline"

# !git clone https://{github_token}@github.com/{username}/{repo}.git

# %cd {repo}

# !git config --global user.email "ala111alot@gmail.com"
# !git config --global user.name "Alanoud Alotaibi"

print("The repository has been successfully and securely linked to GitHub!")
# Out:
# Cloning into 'sdaia-capstone-data-pipeline'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/sdaia-capstone-data-pipeline/sdaia-capstone-data-pipeline/sdaia-capstone-data-pipeline
# The repository has been successfully and securely linked to GitHub!

# %%
# !git add .
# !git commit -m "تحديث الملفات"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Permission to Alanoud-Alotaibi/sdaia-capstone-data-pipeline.git denied to Alanoud-Alotaibi.
# fatal: unable to access 'https://github.com/Alanoud-Alotaibi/sdaia-capstone-data-pipeline.git/': The requested URL returned error: 403

# %%
from google.colab import userdata

github_token = userdata.get('GITHUB')
username = "Alanoud-Alotaibi"
repo = "sdaia-capstone-data-pipeline"

# !git remote set-url origin https://{github_token}@github.com/{username}/{repo}.git

print("تم تحديث رابط الرفع بنجاح!")
# Out:
# تم تحديث رابط الرفع بنجاح!

# %%
# !git add .
# !git commit -m "تحديث الملفات"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
with open("test_file.txt", "w", encoding="utf-8") as f:
    f.write("تجربة الرفع بنجاح من كولاب إلى جيت هب!")
print("تم إنشاء الملف التجريبي")
# Out:
# تم إنشاء الملف التجريبي

# %%
# !git add .
# !git commit -m "تجرية رفع ملف جديد"
# !git push origin main
# Out:
# [main c3b7c50] تجرية رفع ملف جديد
#  1 file changed, 1 insertion(+)
#  create mode 100644 test_file.txt
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 373 bytes | 373.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Alanoud-Alotaibi/sdaia-capstone-data-pipeline.git
#    d65afb4..c3b7c50  main -> main
